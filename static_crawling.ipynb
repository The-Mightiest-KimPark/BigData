# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from pyvirtualdisplay import Display
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []
ingredient_name = []
ingredient_name_list = []
seasoning_name = []
seasoning_name_list = []

recipe_num = 6907317
check_num = 1;

while True:
    req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
    html = req.text
    if len(html) < 100:
        while True:
            recipe_num -= 1;
            req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
            html = req.text
            if len(html) > 200:
                break;
        
    bs = BeautifulSoup(html, 'html.parser')
    
    # 크롤링 확인용
    print(check_num, ':', recipe_num, sep='', end=', ')
    
    # 음식이름
    d_food = bs.select('#contents_area > div.view2_summary.st3 > h3')
    food = [dom.text for dom in d_food]
    food_str = ''.join(food)
    food = []
    food_list.append(food_str)

    # 재료
    d_ingredient = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1)')
    ingredient_str = [dom.text for dom in d_ingredient]
    ingredient_str = ''.join(ingredient_str).split()[1:]
    ingredient_list.append(ingredient_str)
    ingredient_str = []

    
    # 재료명 (유사도검사를 위한)
    inum = 1;
    while True:
        d_ingredient_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1) > a:nth-of-type('+ str(inum) +') > li')
        if not d_ingredient_name :
            break;
        inum += 1;
        ingredient_name_str = [dom.text for dom in d_ingredient_name]
        ingredient_name_str = ''.join(ingredient_name_str).split()[0]
        ingredient_name.append(ingredient_name_str)
        ingredient_name_str = []
    ingredient_name = ' '.join(ingredient_name)
    ingredient_name_list.append(ingredient_name)
    ingredient_name = []
    
    # 양념
    d_seasoning = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2)')
    seasoning_str = [dom.text for dom in d_seasoning]
    seasoning_str = ''.join(seasoning_str).split()[1:]
    seasoning_list.append(seasoning_str)
    seasoning_str = []

    
    # 양념 재료명 (유사도검사를 위한)
    snum = 1;
    while True:
        d_seasoning_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2) > a:nth-of-type('+ str(snum) +') > li')
        if not d_seasoning_name :
            break;
        snum += 1;
        seasoning_name_str = [dom.text for dom in d_seasoning_name]
        seasoning_name_str = ''.join(seasoning_name_str).split()[0]
        seasoning_name.append(seasoning_name_str)
        seasoning_name_str = []
    seasoning_name = ' '.join(seasoning_name)
    seasoning_name_list.append(seasoning_name)
    seasoning_name = []
    

    # 조리방법
    cnum = 1;
    while True:
        d_howto = bs.select('#stepdescr'+ str(cnum))
        hlist = [dom.text for dom in d_howto]
        if not hlist:
            break;        
        hlist = hlist[0]
        howtolist = str(cnum) + '. ' + hlist
        how_to_str.append(howtolist)
        hlist = []
        cnum += 1;
    if not how_to_str:
        d_howto = bs.select('.view_step')
        hlist = [dom.text for dom in d_howto][0].replace('원본보기', '').replace('\n', '')
        how_to_str = hlist.split("\r")[0].split('\xa0')
        how_to_str = [a for a in how_to_str if a]
        hlist = []
    how_to_list.append(how_to_str)
    how_to_str = []
    
    recipe_num_list.append(recipe_num)
    
    recipe_num -= 1;
    check_num += 1;
    if recipe_num == 6897317:
        break;
    

df = pd.DataFrame({"name" : food_list,
                   "ingredient" : ingredient_list,
                   "ingredient_name" : ingredient_name_list,
                   "seasoning" : seasoning_list,
                   "seasoning_name" : seasoning_name_list,
                   "howto" : how_to_list,
                   "recipe_num" : recipe_num_list})  

df.to_csv("./output/최종레시피5.csv", index=False)
        
print("time: ", time.time()-start)
# Out:
# 1:6907317, 2:6907316, 3:6907315, 4:6907314, 5:6907313, 6:6907312, 7:6907311, 8:6907310, 9:6907309, 10:6907308, 11:6907307, 12:6907306, 13:6907305, 14:6907304, 15:6907303, 16:6907302, 17:6907301, 18:6907300, 19:6907299, 20:6907298, 21:6907297, 22:6907296, 23:6907295, 24:6907294, 25:6907293, 26:6907292, 27:6907291, 28:6907290, 29:6907289, 30:6907288, 31:6907287, 32:6907286, 33:6907285, 34:6907284, 35:6907283, 36:6907282, 37:6907281, 38:6907280, 39:6907279, 40:6907278, 41:6907277, 42:6907276, 43:6907275, 44:6907274, 45:6907273, 46:6907272, 47:6907271, 48:6907270, 49:6907269, 50:6907268, 51:6907267, 52:6907266, 53:6907265, 54:6907264, 55:6907263, 56:6907262, 57:6907261, 58:6907260, 59:6907259, 60:6907258, 61:6907257, 62:6907256, 63:6907255, 64:6907254, 65:6907253, 66:6907252, 67:6907250, 68:6907249, 69:6907248, 70:6907247, 71:6907246, 72:6907245, 73:6907244, 74:6907243, 75:6907242, 76:6907241, 77:6907240, 78:6907239, 79:6907238, 80:6907237, 81:6907236, 82:6907235, 83:6907234, 84:6907233, 85:6907232, 86:6907231, 87:6907230, 88:6907229, 89:6907228, 90:6907227, 91:6907226, 92:6907225, 93:6907224, 94:6907223, 95:6907222, 96:6907221, 97:6907220, 98:6907219, 99:6907218, 100:6907217, 101:6907216, 102:6907215, 103:6907214, 104:6907213, 105:6907212, 106:6907211, 107:6907210, 108:6907209, 109:6907208, 110:6907207, 111:6907206, 112:6907205, 113:6907204, 114:6907203, 115:6907202, 116:6907201, 117:6907200, 118:6907199, 119:6907198, 120:6907197, 121:6907196, 122:6907195, 123:6907194, 124:6907193, 125:6907192, 126:6907191, 127:6907190, 128:6907189, 129:6907188, 130:6907187, 131:6907186, 132:6907185, 133:6907184, 134:6907183, 135:6907182, 136:6907181, 137:6907180, 138:6907179, 139:6907178, 140:6907177, 141:6907176, 142:6907175, 143:6907174, 144:6907173, 145:6907172, 146:6907171, 147:6907170, 148:6907169, 149:6907168, 150:6907167, 151:6907166, 152:6907165, 153:6907164, 154:6907163, 155:6907162, 156:6907161, 157:6907160, 158:6907159, 159:6907158, 160:6907157, 161:6907156, 162:6907155, 163:6907154, 164:6907153, 165:6907152, 166:6907151, 167:6907150, 168:6907149, 169:6907148, 170:6907147, 171:6907146, 172:6907145, 173:6907144, 174:6907143, 175:6907142, 176:6907141, 177:6907140, 178:6907139, 179:6907138, 180:6907137, 181:6907136, 182:6907134, 183:6907133, 184:6907132, 185:6907131, 186:6907130, 187:6907129, 188:6907128, 189:6907127, 190:6907126, 191:6907125, 192:6907124, 193:6907123, 194:6907122, 195:6907121, 196:6907120, 197:6907119, 198:6907118, 199:6907117, 200:6907116, 201:6907115, 202:6907114, 203:6907113, 204:6907112, 205:6907111, 206:6907110, 207:6907109, 208:6907108, 209:6907107, 210:6907105, 211:6907104, 212:6907103, 213:6907102, 214:6907101, 215:6907100, 216:6907099, 217:6907098, 218:6907097, 219:6907096, 220:6907095, 221:6907094, 222:6907093, 223:6907092, 224:6907091, 225:6907090, 226:6907089, 227:6907088, 228:6907087, 229:6907086, 230:6907085, 231:6907084, 232:6907083, 233:6907082, 234:6907081, 235:6907080, 236:6907079, 237:6907078, 238:6907077, 239:6907076, 240:6907075, 241:6907074, 242:6907073, 243:6907072, 244:6907071, 245:6907070, 246:6907069, 247:6907068, 248:6907067, 249:6907066, 250:6907065, 251:6907063, 252:6907062, 253:6907061, 254:6907060, 255:6907059, 256:6907058, 257:6907057, 258:6907056, 259:6907055, 260:6907054, 261:6907053, 262:6907052, 263:6907051, 264:6907050, 265:6907049, 266:6907048, 267:6907047, 268:6907046, 269:6907045, 270:6907044, 271:6907043, 272:6907042, 273:6907041, 274:6907040, 275:6907039, 276:6907038, 277:6907037, 278:6907036, 279:6907035, 280:6907034, 281:6907033, 282:6907032, 283:6907031, 284:6907030, 285:6907029, 286:6907028, 287:6907027, 288:6907026, 289:6907025, 290:6907024, 291:6907023, 292:6907022, 293:6907021, 294:6907020, 295:6907019, 296:6907018, 297:6907017, 298:6907016, 299:6907015, 300:6907014, 301:6907013, 302:6907012, 303:6907011, 304:6907010, 305:6907009, 306:6907008, 307:6907007, 308:6907006, 309:6907005, 310:6907004, 311:6907003, 312:6907002, 313:6907001, 314:6907000, 315:6906999, 316:6906998,  ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from pyvirtualdisplay import Display
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []

recipe_num = 6947317
check_num = 1;

while True:
    req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
    html = req.text
    if len(html) < 100:
        while True:
            recipe_num -= 1;
            req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
            html = req.text
            if len(html) > 200:
                break;
        
    bs = BeautifulSoup(html, 'html.parser')
    
    print(check_num, ':', recipe_num, sep='', end=', ')
    # 음식이름
    d_food = bs.select('#contents_area > div.view2_summary.st3 > h3')
    food = [dom.text for dom in d_food]
    food_str = ''.join(food)
    food = []
    food_list.append(food_str)

    # 재료
    d_ingredient = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1)')
    ingredient_str = [dom.text for dom in d_ingredient]
    ingredient_str = ''.join(ingredient_str).split()[1:]
    ingredient_list.append(ingredient_str)
    ingredient_str = []



    # 양념
    d_seasoning = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2)')
    seasoning_str = [dom.text for dom in d_seasoning]
    seasoning_str = ''.join(seasoning_str).split()[1:]
    seasoning_list.append(seasoning_str)
    seasoning_str = []


    # 조리방법
    cnum = 1;
    while True:
        d_howto = bs.select('#stepdescr'+ str(cnum))
        hlist = [dom.text for dom in d_howto]
        if not hlist:
            break;        
        hlist = hlist[0]
        howtolist = str(cnum) + '. ' + hlist
        how_to_str.append(howtolist)
        hlist = []
        cnum += 1;
    if not how_to_str:
        d_howto = bs.select('.view_step')
        hlist = [dom.text for dom in d_howto][0].replace('원본보기', '').replace('\n', '')
        how_to_str = hlist.split("\r")[0].split('\xa0')
        how_to_str = [a for a in how_to_str if a]
        hlist = []
    how_to_list.append(how_to_str)
    how_to_str = []
    
    recipe_num_list.append(recipe_num)
    
    recipe_num -= 1;
    check_num += 1;
    if recipe_num == 6927317:
        break;
    

df = pd.DataFrame({"name" : food_list,
                   "ingredient" : ingredient_list,
                   "seasoning" : seasoning_list,
                   "howto" : how_to_list,
                   "recipe_num" : recipe_num_list})  

df.to_csv("./output/recipe_2.csv", index=False)
        
print("time: ", time.time()-start)

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []
ingredient_name = []
ingredient_name_list = []

recipe_num = 6947317
check_num = 1;

req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
html = req.text       
bs = BeautifulSoup(html, 'html.parser')

num = 1;
while True:
    # 재료명 (유사도검사를 위한)
    d_ingredient_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2) > a:nth-of-type('+ str(num) +')')
    if not d_ingredient_name :
        break;
    num += 1;
    ingredient_name_str = [dom.text for dom in d_ingredient_name]
    ingredient_name_str = ''.join(ingredient_name_str).split()[0]
    ingredient_name.append(ingredient_name_str)
    ingredient_name_str = []

ingredient_name = ' '.join(ingredient_name)
ingredient_name_list.append(ingredient_name)
ingredient_name = []
print(ingredient_name_list)
# Out:
# ['간장 다진마늘 올리고당 참기름']
